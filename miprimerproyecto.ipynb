# %% [markdown]
# <a href="https://colab.research.google.com/github/davidrivaszz/PrograsemiII2026/blob/main/miprimerproyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "hola chicos de progra III"
print(saludo)
# Out:
# hola chicos de progra III

# %%
print("sumar dos numeros:")
num1 = input("num 1:")
num2 = input("num2:")
respuesta = float(num1) + float(num2)
print (type(num1), type(num2), type(respuesta))
print("respuesta:", respuesta)
respuesta = "ssuma completa"
print(respuesta, type(respuesta))
# Out:
# sumar dos numeros:
# num 1:5.5
# num2:6
# <class 'str'> <class 'str'> <class 'float'>
# respuesta: 11.5
# ssuma completa <class 'str'>

# %%
print("restar dos numeros:")
num1 = input("num 1:")
num2 = input("num2:")
respuesta = float(num1) - float(num2)

print("respuesta:", respuesta)
# Out:
# restar dos numeros:
# num 1:20
# num2:15
# respuesta: 5.0

# %%
print("multiplicar dos numeros:")
num1 = input("num 1:")
num2 = input("num2:")
respuesta = float(num1) * float(num2)

print("respuesta:", respuesta)
# Out:
# multiplicar dos numeros:
# num 1:1
# num2:1
# respuesta: 1.0

# %%
print("dividir dos numeros:")
num1 = input("num 1:")
num2 = input("num2:")
respuesta = float(num1) / float(num2)

print("respuesta:", respuesta)
# Out:
# dividir dos numeros:
# num 1:10
# num2:5
# respuesta: 2.0
